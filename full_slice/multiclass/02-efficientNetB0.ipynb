# %%
from dataclasses import dataclass
import pandas as pd
import os
import SimpleITK as sitk

import keras as tfk
from keras import layers as tfkl

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.regularizers import l2
from tensorflow.data import Dataset as tfds
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

sns.set_theme()

# %%
SEED = 42
BATCH_SIZE = 32
IMG_HEIGHT = 512
IMG_WIDTH = 512
SHUFFLE_BUFFER_SIZE = 100
METRICS = ["accuracy", "recall", "f1_score"]

data_dir = '/kaggle/input/lung-ds-norm/Full_slice'

tfk.utils.set_random_seed(SEED)

# %%
train_datagen = ImageDataGenerator(
    rotation_range=30,            
    width_shift_range=0.2,        
    height_shift_range=0.2,       
    shear_range=0.2,              
    zoom_range=0.2,               
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='constant',
    cval=0    
)

val_datagen = ImageDataGenerator(

)

train_generator = train_datagen.flow_from_directory(
    data_dir + "/train",
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
    #subset='training'               
)

val_generator = val_datagen.flow_from_directory(
    data_dir + "/val",
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical'
    #subset='val'
)
# Out:
# Found 1885 images belonging to 5 classes.
# Found 475 images belonging to 5 classes.

# %%
# Get one batch of augmented images
augmented_images, _ = next(train_generator)  # Ignore labels (_)

# Plot a 5x5 grid of augmented images
fig, axes = plt.subplots(5, 5, figsize=(12, 12))
axes = axes.flatten()

for img, ax in zip(augmented_images[:25], axes):  # Take the first 25 images
    ax.imshow(img[:, :, 0], cmap='gray')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
@dataclass
class Hyperparameters:
    # Model
    activation = "relu"
    # Training
    noise_std: float = 0.05 # then try 0.1
    optimiser = tfk.optimizers.Adam
    learning_rate = 1e-4
    weight_decay = 1e-4
    regularization1 = tfk.regularizers.L1L2(l1=1e-5, l2=0)
    regularization2 = tfk.regularizers.L1L2(l1=0, l2=0)
    loss = tfk.losses.CategoricalCrossentropy()
    epochs = 50
    ## Early stopping parameters
    es_patience = 10
    es_min_delta = 1e-2
    ## Learning rate schedule
    lr_patience = 5
    lr_decay_factor = 0.3
    lr_min_delta = 5e-2 
    min_lr = 1e-6

hp = Hyperparameters()

# %%
def build_model(hp: Hyperparameters,
                feature_extractor: tfk.applications):
    
    inputs = tfkl.Input((IMG_HEIGHT, IMG_WIDTH, 3))

    x = tfkl.Rescaling(1./255)(inputs)
    gn = tfkl.GaussianNoise(hp.noise_std)(x)
    x = tfkl.Rescaling(255)(gn)

    backbone_output = feature_extractor(x)

    conv_layer = tfkl.Conv2D(1024, kernel_size=(3, 3), activation='relu', padding='same')(backbone_output) 
    max_pool_layer = tfkl.MaxPooling2D(pool_size=(2, 2))(conv_layer)
    flatten_layer = tfkl.Flatten()(max_pool_layer) 

    x = tfkl.Dropout(0.6)(flatten_layer)

    x = tfkl.Dense(1024, activation='relu')(x)
    x = tfkl.Dense(512, activation='relu')(x)
    x = tfkl.Dense(256, activation='relu')(x)
    #x = tfkl.Dense(128, activation='relu')(x)

    x = tfkl.Dropout(0.4)(x)

    output = tfkl.Dense(5, activation="softmax")(x)
    
    model = tfk.Model(inputs, output)
    return model

# %%
def fit(model: tfk.Model,
        train_generator: ImageDataGenerator,
        val_generator: ImageDataGenerator,
        hp: Hyperparameters):
    model.compile(loss=hp.loss,
                  optimizer=hp.optimiser(learning_rate=hp.learning_rate, weight_decay=hp.weight_decay), 
                  metrics=['accuracy'])
    
    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=hp.epochs,
        #validation_data=val_dataset,
        callbacks=[
            tfk.callbacks.EarlyStopping(monitor='val_loss', 
                                        #mode='min',
                                        patience=hp.es_patience, 
                                        restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(
                factor=hp.lr_decay_factor,
                patience=hp.lr_patience,
                min_delta=hp.lr_min_delta,
                min_lr=hp.min_lr,
                verbose=1,
            )
    ]
    
    ).history

    return model, history

# %%
backbone = tfk.applications.EfficientNetB0(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape=(512,512,3),
    pooling=None #'avg'
)

backbone.trainable = False

model = build_model(hp, backbone)

model, history = fit(model, train_generator, val_generator, hp)
# Out:
# Epoch 1/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 134s 2s/step - accuracy: 0.2187 - loss: 2.2770 - val_accuracy: 0.2611 - val_loss: 1.5946 - learning_rate: 1.0000e-04
# Epoch 2/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.2307 - loss: 1.6210 - val_accuracy: 0.2968 - val_loss: 1.5556 - learning_rate: 1.0000e-04
# Epoch 3/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.2802 - loss: 1.5838 - val_accuracy: 0.2821 - val_loss: 1.5526 - learning_rate: 1.0000e-04
# Epoch 4/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.2734 - loss: 1.5696 - val_accuracy: 0.3158 - val_loss: 1.5317 - learning_rate: 1.0000e-04
# Epoch 5/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.3109 - loss: 1.5606 - val_accuracy: 0.3411 - val_loss: 1.5163 - learning_rate: 1.0000e-04
# Epoch 6/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.3170 - loss: 1.5274 - val_accuracy: 0.3558 - val_loss: 1.4864 - learning_rate: 1.0000e-04
# Epoch 7/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.3404 - loss: 1.5093 - val_accuracy: 0.3137 - val_loss: 1.5254 - learning_rate: 1.0000e-04
# Epoch 8/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.3490 - loss: 1.5063 - val_accuracy: 0.3832 - val_loss: 1.4491 - learning_rate: 1.0000e-04
# Epoch 9/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.3714 - loss: 1.4627 - val_accuracy: 0.4232 - val_loss: 1.4258 - learning_rate: 1.0000e-04
# Epoch 10/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.3611 - loss: 1.4480 - val_accuracy: 0.4000 - val_loss: 1.3977 - learning_rate: 1.0000e-04
# Epoch 11/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.3909 - loss: 1.4206 - val_accuracy: 0.3347 - val_loss: 1.4746 - learning_rate: 1.0000e-04
# Epoch 12/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.3759 - loss: 1.4084 - val_accuracy: 0.3558 - val_loss: 1.4695 - learning_rate: 1.0000e-04
# Epoch 13/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.4163 - loss: 1.3802 - val_accuracy: 0.3663 - val_loss: 1.3887 - learning_rate: 1.0000e-04
# Epoch 14/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.4003 - loss: 1.3786 - val_accuracy: 0.4337 - val_loss: 1.3199 - learning_rate: 1.0000e-04
# Epoch 15/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.4312 - loss: 1.3221 - val_accuracy: 0.4505 - val_loss: 1.3135 - learning_rate: 1.0000e-04
# Epoch 16/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.4400 - loss: 1.3317 - val_accuracy: 0.4484 - val_loss: 1.2944 - learning_rate: 1.0000e-04
# Epoch 17/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.4664 - loss: 1.2710 - val_accuracy: 0.4821 - val_loss: 1.2575 - learning_rate: 1.0000e-04
# Epoch 18/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.4698 - loss: 1.2994 - val_accuracy: 0.4716 - val_loss: 1.2577 - learning_rate: 1.0000e-04
# Epoch 19/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.4876 - loss: 1.2657 - val_accuracy: 0.4463 - val_loss: 1.3094 - learning_rate: 1.0000e-04
# Epoch 20/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.4966 - loss: 1.2247 - val_accuracy: 0.4800 - val_loss: 1.2446 - learning_rate: 1.0000e-04
# Epoch 21/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.4966 - loss: 1.2024 - val_accuracy: 0.4821 - val_loss: 1.2455 - learning_rate: 1.0000e-04
# Epoch 22/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.5420 - loss: 1.1458 - val_accuracy: 0.5032 - val_loss: 1.1976 - learning_rate: 1.0000e-04
# Epoch 23/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.5081 - loss: 1.1660 - val_accuracy: 0.5516 - val_loss: 1.1275 - learning_rate: 1.0000e-04
# Epoch 24/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.5596 - loss: 1.1279 - val_accuracy: 0.5158 - val_loss: 1.1889 - learning_rate: 1.0000e-04
# Epoch 25/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.5452 - loss: 1.1166 - val_accuracy: 0.5579 - val_loss: 1.1121 - learning_rate: 1.0000e-04
# Epoch 26/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.5461 - loss: 1.0645 - val_accuracy: 0.5495 - val_loss: 1.1619 - learning_rate: 1.0000e-04
# Epoch 27/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.5579 - loss: 1.1020 - val_accuracy: 0.5074 - val_loss: 1.1839 - learning_rate: 1.0000e-04
# Epoch 28/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5573 - loss: 1.0911
# Epoch 28: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.5572 - loss: 1.0912 - val_accuracy: 0.5642 - val_loss: 1.1473 - learning_rate: 1.0000e-04
# Epoch 29/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.5900 - loss: 1.0244 - val_accuracy: 0.5432 - val_loss: 1.1226 - learning_rate: 3.0000e-05
# Epoch 30/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6401 - loss: 0.9239 - val_accuracy: 0.5811 - val_loss: 1.0974 - learning_rate: 3.0000e-05
# Epoch 31/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.6181 - loss: 0.9634 - val_accuracy: 0.5832 - val_loss: 1.1001 - learning_rate: 3.0000e-05
# Epoch 32/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.6613 - loss: 0.8761 - val_accuracy: 0.5937 - val_loss: 1.1113 - learning_rate: 3.0000e-05
# Epoch 33/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6633 - loss: 0.8889 - val_accuracy: 0.6337 - val_loss: 1.0435 - learning_rate: 3.0000e-05
# Epoch 34/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.6464 - loss: 0.9102 - val_accuracy: 0.6211 - val_loss: 1.0467 - learning_rate: 3.0000e-05
# Epoch 35/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 104s 2s/step - accuracy: 0.6644 - loss: 0.8689 - val_accuracy: 0.6084 - val_loss: 1.0573 - learning_rate: 3.0000e-05
# Epoch 36/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 107s 2s/step - accuracy: 0.6723 - loss: 0.8380 - val_accuracy: 0.6253 - val_loss: 1.0496 - learning_rate: 3.0000e-05
# Epoch 37/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.6870 - loss: 0.8139 - val_accuracy: 0.6274 - val_loss: 1.0404 - learning_rate: 3.0000e-05
# Epoch 38/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6733 - loss: 0.8267
# Epoch 38: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6736 - loss: 0.8263 - val_accuracy: 0.6168 - val_loss: 1.0566 - learning_rate: 3.0000e-05
# Epoch 39/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6946 - loss: 0.7884 - val_accuracy: 0.6232 - val_loss: 1.0415 - learning_rate: 9.0000e-06
# Epoch 40/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6911 - loss: 0.7822 - val_accuracy: 0.6274 - val_loss: 1.0366 - learning_rate: 9.0000e-06
# Epoch 41/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.7030 - loss: 0.8014 - val_accuracy: 0.6358 - val_loss: 1.0236 - learning_rate: 9.0000e-06
# Epoch 42/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6952 - loss: 0.7540 - val_accuracy: 0.6358 - val_loss: 1.0269 - learning_rate: 9.0000e-06
# Epoch 43/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6915 - loss: 0.7738
# Epoch 43: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6918 - loss: 0.7735 - val_accuracy: 0.6358 - val_loss: 1.0234 - learning_rate: 9.0000e-06
# Epoch 44/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6975 - loss: 0.7722 - val_accuracy: 0.6379 - val_loss: 1.0275 - learning_rate: 2.7000e-06
# Epoch 45/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6812 - loss: 0.7914 - val_accuracy: 0.6337 - val_loss: 1.0274 - learning_rate: 2.7000e-06
# Epoch 46/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 106s 2s/step - accuracy: 0.7399 - loss: 0.7230 - val_accuracy: 0.6442 - val_loss: 1.0200 - learning_rate: 2.7000e-06
# Epoch 47/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.7261 - loss: 0.7060 - val_accuracy: 0.6442 - val_loss: 1.0221 - learning_rate: 2.7000e-06
# Epoch 48/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6963 - loss: 0.7935
# Epoch 48: ReduceLROnPlateau reducing learning rate to 1e-06.
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.6965 - loss: 0.7931 - val_accuracy: 0.6358 - val_loss: 1.0221 - learning_rate: 2.7000e-06
# Epoch 49/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.7273 - loss: 0.7405 - val_accuracy: 0.6421 - val_loss: 1.0167 - learning_rate: 1.0000e-06
# Epoch 50/50
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.7084 - loss: 0.7557 - val_accuracy: 0.6442 - val_loss: 1.0171 - learning_rate: 1.0000e-06

# %%
# Plot loss curves
plt.style.use('default')
plt.plot(history['loss'], label='Train loss', alpha=0.3, linestyle='--')
plt.plot(history['val_loss'], label='Val loss', alpha=0.8)
plt.title('Categorical Crossentropy Loss')
plt.legend(loc='upper left')
plt.grid(alpha=0.3)

# %%
# Plot accuracy curves
plt.style.use('default')
plt.plot(history['accuracy'], label='Train accuracy', alpha=0.3, linestyle='--')
plt.plot(history['val_accuracy'], label='Val accuracy', alpha=0.8)
plt.title('Accuracy')
plt.legend(loc='upper left')
plt.grid(alpha=0.3)

# %%
# Predict on validation data and plot confusion matrix
y_true = []
for _, labels in val_generator:
    y_true.extend(labels)
    if len(y_true) >= val_generator.samples:  # Stop when all samples are processed
        break
y_true = np.array(y_true)

if val_generator.class_mode == 'categorical':
    y_true = np.argmax(y_true, axis=1)  # Convert one-hot to class indices

y_pred = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert probabilities to class indices
print("Accuracy: ", accuracy_score(y_true, y_pred_classes))

cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=val_generator.class_indices.keys(), yticklabels=val_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 15s 708ms/step
# Accuracy:  0.6421052631578947
