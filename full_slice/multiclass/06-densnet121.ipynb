# %%
from dataclasses import dataclass
import pandas as pd
import os
import SimpleITK as sitk

import keras as tfk
from keras import layers as tfkl

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras.regularizers import l2
from tensorflow.data import Dataset as tfds
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

sns.set_theme()

# %%
SEED = 42
BATCH_SIZE = 64

IMG_HEIGHT = 224
IMG_WIDTH = 224
METRICS = ["accuracy", "recall", "f1_score"]

data_dir = '/kaggle/input/lung-ds/Full_slice'

tfk.utils.set_random_seed(SEED)

# %%
from tensorflow.keras.applications.mobilenet import preprocess_input


train_datagen = ImageDataGenerator(
    #rescale=1.0/255,
    preprocessing_function=preprocess_input,
    rotation_range=10,            
    #width_shift_range=0.2,        
    #height_shift_range=0.2,       
    shear_range=0.15,              
    zoom_range=0.15,               
    #horizontal_flip=True,
    #vertical_flip=True,
    fill_mode='nearest' 
    
)

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input
)

train_generator = train_datagen.flow_from_directory(
    data_dir + "/train",
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42,
    #shuffle=False
    #subset='training'               
)

val_generator = val_datagen.flow_from_directory(
    data_dir + "/val",
    target_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=42,
    #shuffle=False
    #subset='val'
)
# Out:
# Found 1890 images belonging to 5 classes.
# Found 473 images belonging to 5 classes.

# %%
class_indices = train_generator.class_indices
num_classes = len(class_indices)

labels = train_generator.classes 

class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(labels),
    y=labels
)

class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

class_weight_dict
# Out:
# {0: 1.9285714285714286,
#  1: 1.052924791086351,
#  2: 0.42615558060879366,
#  3: 1.148936170212766,
#  4: 3.176470588235294}

# %%
@dataclass
class Hyperparameters:
    # Model
    activation = "silu"
    # Training
    noise_std: float = 0.05 # then try 0.1
    optimiser = tfk.optimizers.Adam
    learning_rate = 1e-4
    weight_decay = 1e-4
    regularization1 = tfk.regularizers.L1L2(l1=1e-5, l2=0)
    regularization2 = tfk.regularizers.L1L2(l1=0, l2=0)
    loss = tfk.losses.CategoricalCrossentropy()
    epochs = 50
    ## Early stopping parameters
    es_patience = 15
    es_min_delta = 1e-2
    ## Learning rate schedule
    lr_patience = 5
    lr_decay_factor = 0.3
    lr_min_delta = 1e-2 
    min_lr = 1e-6

hp = Hyperparameters()

# %%
def build_model(hp: Hyperparameters,
                feature_extractor: tfk.applications):
    
    #inputs = tfkl.Input((IMG_HEIGHT, IMG_WIDTH, 3))

    backbone_output = feature_extractor.output

    x=tfkl.GlobalAveragePooling2D()(backbone_output)
    x=tfkl.Dense(128, activation='relu')(x)
    x=tfkl.Dropout(0.4)(x)
    
    out=tfkl.Dense(5,activation='softmax')(x)
    
    model = tfk.Model(inputs=feature_extractor.input, outputs=out)
    return model

# %%
def fit(model: tfk.Model,
        train_generator: ImageDataGenerator,
        val_generator: ImageDataGenerator,
        hp: Hyperparameters,
        class_weights = None):
    model.compile(loss=hp.loss,
                  optimizer=hp.optimiser(learning_rate=hp.learning_rate), #, weight_decay=hp.weight_decay), 
                  metrics=['accuracy'])
    
    history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=hp.epochs,
        class_weight=class_weights,
        #validation_data=val_dataset,
        callbacks=[
            tfk.callbacks.EarlyStopping(monitor='val_loss', 
                                        #mode='min',
                                        patience=hp.es_patience, 
                                        restore_best_weights=True),
            tfk.callbacks.ReduceLROnPlateau(
                factor=hp.lr_decay_factor,
                patience=hp.lr_patience,
                min_delta=hp.lr_min_delta,
                min_lr=hp.min_lr,
                verbose=1,
            )
    ]
    
    ).history

    return model, history

# %%
backbone = tfk.applications.MobileNetV2(
    include_top=False,
    weights='imagenet',
    input_shape=(IMG_HEIGHT,IMG_WIDTH,3),
    #pooling='avg'
)

#backbone.summary()

#backbone.trainable = True

for layer in backbone.layers:
    layer.trainable= False

model = build_model(hp, backbone)

model, history = fit(model, train_generator, val_generator, hp, class_weight_dict)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.2113 - loss: 2.2874 - val_accuracy: 0.1564 - val_loss: 1.7542 - learning_rate: 1.0000e-04
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.1954 - loss: 1.9575 - val_accuracy: 0.2347 - val_loss: 1.6474 - learning_rate: 1.0000e-04
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.2231 - loss: 1.7883 - val_accuracy: 0.2220 - val_loss: 1.6283 - learning_rate: 1.0000e-04
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2106 - loss: 1.6919 - val_accuracy: 0.2389 - val_loss: 1.6190 - learning_rate: 1.0000e-04
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2182 - loss: 1.6419 - val_accuracy: 0.2156 - val_loss: 1.6561 - learning_rate: 1.0000e-04
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2103 - loss: 1.6472 - val_accuracy: 0.2114 - val_loss: 1.6178 - learning_rate: 1.0000e-04
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2291 - loss: 1.6506 - val_accuracy: 0.2178 - val_loss: 1.6135 - learning_rate: 1.0000e-04
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.2607 - loss: 1.5831 - val_accuracy: 0.2093 - val_loss: 1.6207 - learning_rate: 1.0000e-04
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2513 - loss: 1.5684 - val_accuracy: 0.2156 - val_loss: 1.6058 - learning_rate: 1.0000e-04
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2504 - loss: 1.5933 - val_accuracy: 0.2199 - val_loss: 1.6047 - learning_rate: 1.0000e-04
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2424 - loss: 1.5534 - val_accuracy: 0.2093 - val_loss: 1.6158 - learning_rate: 1.0000e-04
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2482 - loss: 1.5944 - val_accuracy: 0.2135 - val_loss: 1.5946 - learning_rate: 1.0000e-04
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.2721 - loss: 1.5420 - val_accuracy: 0.2241 - val_loss: 1.5954 - learning_rate: 1.0000e-04
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2741 - loss: 1.5487 - val_accuracy: 0.2156 - val_loss: 1.5949 - learning_rate: 1.0000e-04
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2613 - loss: 1.5431 - val_accuracy: 0.2114 - val_loss: 1.5977 - learning_rate: 1.0000e-04
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2663 - loss: 1.5485 - val_accuracy: 0.2431 - val_loss: 1.5923 - learning_rate: 1.0000e-04
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 854ms/step - accuracy: 0.2360 - loss: 1.5605
# Epoch 17: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.2367 - loss: 1.5595 - val_accuracy: 0.2410 - val_loss: 1.5909 - learning_rate: 1.0000e-04
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2537 - loss: 1.5974 - val_accuracy: 0.2199 - val_loss: 1.5919 - learning_rate: 3.0000e-05
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.2701 - loss: 1.5527 - val_accuracy: 0.2135 - val_loss: 1.5975 - learning_rate: 3.0000e-05
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2689 - loss: 1.5140 - val_accuracy: 0.2241 - val_loss: 1.5914 - learning_rate: 3.0000e-05
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2439 - loss: 1.5772 - val_accuracy: 0.2135 - val_loss: 1.5982 - learning_rate: 3.0000e-05
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 867ms/step - accuracy: 0.2822 - loss: 1.5176
# Epoch 22: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2821 - loss: 1.5178 - val_accuracy: 0.2114 - val_loss: 1.5946 - learning_rate: 3.0000e-05
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.3049 - loss: 1.4925 - val_accuracy: 0.2241 - val_loss: 1.5908 - learning_rate: 9.0000e-06
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2749 - loss: 1.5241 - val_accuracy: 0.2199 - val_loss: 1.5926 - learning_rate: 9.0000e-06
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2512 - loss: 1.5307 - val_accuracy: 0.2220 - val_loss: 1.5954 - learning_rate: 9.0000e-06
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.2493 - loss: 1.4657 - val_accuracy: 0.2220 - val_loss: 1.5925 - learning_rate: 9.0000e-06
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.2407 - loss: 1.5370
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2413 - loss: 1.5369 - val_accuracy: 0.2156 - val_loss: 1.5953 - learning_rate: 9.0000e-06
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2881 - loss: 1.5351 - val_accuracy: 0.2156 - val_loss: 1.5947 - learning_rate: 2.7000e-06
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.2781 - loss: 1.4997 - val_accuracy: 0.2156 - val_loss: 1.5948 - learning_rate: 2.7000e-06
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.2778 - loss: 1.5697 - val_accuracy: 0.2156 - val_loss: 1.5953 - learning_rate: 2.7000e-06
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2571 - loss: 1.5457 - val_accuracy: 0.2199 - val_loss: 1.5953 - learning_rate: 2.7000e-06
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 864ms/step - accuracy: 0.2742 - loss: 1.4877
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1e-06.
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2743 - loss: 1.4885 - val_accuracy: 0.2220 - val_loss: 1.5937 - learning_rate: 2.7000e-06
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.2791 - loss: 1.5231 - val_accuracy: 0.2220 - val_loss: 1.5938 - learning_rate: 1.0000e-06
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.2862 - loss: 1.5230 - val_accuracy: 0.2220 - val_loss: 1.5938 - learning_rate: 1.0000e-06
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.2716 - loss: 1.5101 - val_accuracy: 0.2241 - val_loss: 1.5937 - learning_rate: 1.0000e-06
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2520 - loss: 1.5062 - val_accuracy: 0.2241 - val_loss: 1.5933 - learning_rate: 1.0000e-06
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2700 - loss: 1.5017 - val_accuracy: 0.2241 - val_loss: 1.5930 - learning_rate: 1.0000e-06
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.2798 - loss: 1.5055 - val_accuracy: 0.2241 - val_loss: 1.5931 - learning_rate: 1.0000e-06

# %%
# Plot loss curves
plt.style.use('default')
plt.plot(history['loss'], label='Train loss', alpha=0.3, linestyle='--')
plt.plot(history['val_loss'], label='Val loss', alpha=0.8)
plt.title('Categorical Crossentropy Loss')
plt.legend(loc='upper left')
plt.grid(alpha=0.3)

# %%
# Plot accuracy curves
plt.style.use('default')
plt.plot(history['accuracy'], label='Train accuracy', alpha=0.3, linestyle='--')
plt.plot(history['val_accuracy'], label='Val accuracy', alpha=0.8)
plt.title('Accuracy')
plt.legend(loc='upper left')
plt.grid(alpha=0.3)

# %%
# Predict on validation data and plot confusion matrix
y_true = []
for _, labels in val_generator:
    y_true.extend(labels)
    if len(y_true) >= val_generator.samples:  # Stop when all samples are processed
        break
y_true = np.array(y_true)

if val_generator.class_mode == 'categorical':
    y_true = np.argmax(y_true, axis=1)  # Convert one-hot to class indices

y_pred = model.predict(val_generator)
y_pred_classes = np.argmax(y_pred, axis=1)  # Convert probabilities to class indices
print("Accuracy: ", accuracy_score(y_true, y_pred_classes))

cm = confusion_matrix(y_true, y_pred_classes)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=val_generator.class_indices.keys(), yticklabels=val_generator.class_indices.keys())
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
